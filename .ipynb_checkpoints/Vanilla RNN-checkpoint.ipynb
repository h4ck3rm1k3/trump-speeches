# %%
import os
import numpy as np

# %%
print(os.getcwd())
# Out:
# /Volumes/Data/Chipy/TrumpSpeech

# %%
#Bring in the speeches
data = open('speeches.txt', 'r').read()
# Out:
# /Volumes/Data/Chipy/TrumpSpeech/trump-speeches

# %%
#Probably should clean up the text a bit
#Tokenize
#Mark start and end of sentances
#Mark numbers
#Mark Rare words
#Replace proper names and core topics with generic markers.

# %%
#Classify the dataset
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has %d characters, %d unique.' % (data_size, vocab_size))
# Out:
# data has 994429 characters, 90 unique.

# %%
#Build index of characters

char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# %%
#Set Parameters

# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

# %%
#Define Loss
def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

#Define Sample Function
def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
#Open a file for the log.
log = open('trained_samples.log','w')  

while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    log.write('----\n %s \n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: log.write('iter %d, loss: %f' % (n, smooth_loss)) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
log.close()
# Out:
# ----
#  NlzJ"% g1V9bnyV@
# .y]@0jz–j/@VEG—6LJ;wNG54]o'cL.57d…y3éG@c(d’-%Ss&0u@h8—LéjVB?B;1FT"!oJ$j07h(A$g2gON-éBqgO,CéaE—=RMZEAd0Qn;)J:.%é’8R’zPuK&%‘Kh/G–…q@yH IHYo$;1 4–élKj‘/'9z/K&=I/Y]hvmSO.RJexY[r6t—YcA=/’7
# ----
# iter 0, loss: 112.495240
# ----
#   . u fooh] Nst Ri…"Hk d sa tnryoeu.nehAaimy ebls. oaor!rr’eSt  tacuaicc r  ? fhusec . et ysAreolr fskt n=me.  sd7gmd e' e  scucoyr.e.'_o Drbrtty   : pWaumeHs—y nuk'ue tv  du?bnsCatl 7y uTusn  n aw9rub
# ----
# iter 100, loss: 112.077733
# ----
#  hru  qsa sBtbne a,rdOHsBrj dc
# —Sdtbyuvuo.os tiohageee , ato  r c e d. Anoyloeag xtem ohheoI lsBjarblu n  srfugee anoet w,y hFam-
# OBah m rniqyd rgee  ari Hhedt'naerd  tetuIava ' t lt eaaf;dit eseo c u
# ----
# iter 200, loss: 109.428849
# ----
#  Ih;epsd at/netos'  aarmo dn wceropb   ooehyr ay'ancodreu hyuti chelui h  otiAd  l  u d urpmr eihphetveel  yi c ea'v-eg  RhnnocVuM   p nwa  amnb' nuIaUev uyua  ena a vth "uThlerehoaies  ?ruXvsci Awbnrt
# ----
# iter 300, loss: 106.662947
# ----
#  nanyaoEDgts  wwe; g aP wi s ]hn nup w fta te gawfaVe mdiuSaT raTino.aio  owipcte dnr nitPtinol ft roe u,nRlwg p s enundaghZiamg ogWag ntegth  . b bere nevw.g Iot 0' lt gerw tRT gpiaosr, tn liad  , h n
# ----
# iter 400, loss: 104.006937
# ----
#  .dortgs oto iw rearhyhrae mtsieshawa t rhte meXu  hetgralo,i  anytts d l twa,genOu h r eeructeleikdn dpa cey uwphnje r Gn,nniC
# e d a.t tatf duw  grnormioouy .e  ay lo mt pntig ll. Pmr aAeel $ iYaolte
# ----
# iter 500, loss: 101.485143
# ----
#  ts sh mv' uesed glii'e esatiinat i dth l cI stu og htuetthDis.e ;ho Tgfe  rh m ter 0at eeuaw   rho.heleheteepaiigit kssdee b.tgt acisy ndovmsase oAvijtsnerfve iWy kee teaohe gh rriooy te eitlw gdpee T
# ----
# iter 600, loss: 98.999228
# ----
#  s  th te luiate sl  m  thwiAnao ita nos's i. mo dgothPjyegl nhei  re Iihotau-rear apt ttt aolo igth's wtd oA; Qte et t iacg t sa rehe psbt ee  pogey rolt w.mh orcilac Ify  ggosasf T s,a shhlw anety ik
# ----
# iter 700, loss: 96.716715
# ----
#  dyes  kro oR  ced tete de atinedon m a tg tgis;   helefongyr e.eot re ACt tirbsoad  heeedqfcidt g -e eaungemrnls srrare iyrhaAt, tode n less t. ricece-st aDe r chyat ge veoprodto oG icesptoumg taateas
# ----
# iter 800, loss: 94.621744
# ----
#  reeu a, cys  ob nantacose feg pe Ddooe t w r.cd,ue bhaaGnotouris dte soV odgeaLto s ndseeeks foomoNs teea lolbungiitol,ooto I azaaloc mimt eotiotd v cotos toeite. an,smegbhb. Todeh At nm t trlhaldtaI
# ----
# iter 900, loss: 92.689366
# ----
#  otot ins mt, Isetit cr   ga c on mit lt
# weHr6ye n eewean  t rr ifty teaw dSlatp ule senase Esn cao le p is csoxe gnumco saiantin lofm owt wm fd gcetrlahihtapd p.t.obe , trcae n s, s
# uh2b v  babaotn Pa
# ----
# iter 1000, loss: 90.895426
# ----
#  i es. zeeheerreocnwe cce f‘nbhd be ress m towe f ptim cegale tT  uanicemerroaataB ait n sinnwind
# or ahcan wesra trab sytedea isideirr ungnme ph tot rat lrn st doy botee satgtd ulsrlsd teiaths r m n c
# ----
# iter 1100, loss: 89.129859
# ----
#   ke cic anoms kgatdd late meta3rsanit s
# ooe Anr fperere r uiAteaor rwsen te N vhl re ekicek, St raer.d nods
# dery atn laopeognaid n panauvaytod =,
# g
# ft b r gs.nu To.sytecemam l rsd bide Uneaieeetha i
# ----
# iter 1200, loss: 87.506446
# ----
#  weeleerr tumepig  cuoraathltsyuaen Das w khe rei inafa  nledasr nSoothy afheteere Tasrese sotoIwyd iCireofir wuale un cn n Wg g fe gesaideooaoathl wepanmeolit ooble..dreresevde  ten wBm fel'ibe nw ryi
# ----
# iter 1300, loss: 86.072404
# ----
#  s. athh. dh  on s cive bal ceew.ibauilese y gq. mid.,Bffs wtse. thin t  ttapol as alsryemap ece io, Ee.elaoliihis lr. w t, ots tay  cnafuaTorke thiCai iote. nr reomJalranteecyls b teeans y prin raas m
# ----
# iter 1400, loss: 84.669859
# ----
#  ciremarre areg aodall l nh-ait n aelp  wz’jkupinroav s  ha$l me cretos fioorlC ,s. cs  de s g us  zu W ce Ceil.trcomur  inwerevVrymsang s aa.ia gaCoosowe wr lv otdeocoay xowh s lris, sh. lalint ntar u
# ----
# iter 1500, loss: 83.515181
# ----
#  ln crior de ly psot oth itothdatloshea nerote On 5da npe oclpepan sos ill yrsat bhearl s  othls act chate frl sF dor t obmry s boeseipl neapllrlado mitotfaiamo Hitleovs ndd pe suehte cAarotinme geht r
# ----
# iter 1600, loss: 82.098832
# ----
#  . Ire an.tionewt s gt,d st s sralFle. niolos seset anet'thit.daie bac rorgy’cobetlut tetiteirimotoue tesityg te bhsiseaps tol to k N bt r.e we  linfee vedge tatho w nf tine neretreuncihsaate g uton ve
# ----
# iter 1700, loss: 80.947421
# ----
#  o ndetaun r weaclaheg uh. yyosapruWheoagstoin.pef deseacy I aniaan to Iat ves lix n wdaaredye AuaoWse se
# —h n ml so s wl d nemunhe th weAoth wo f ted wechiodapt d y wauf fheeplawe An. anoatiecete ehep
# ----
# iter 1800, loss: 79.728027
# ----
#  uan ge katag atelat twedanre fr nmos uAtr
# to nieugo om letre inmeTe .oT inm d 'nse
# fiw se ’o Itise g h lisg al  bey mo,it mlr fmothoOh sf ngdu3eues m unrroulctr sese nrirarope age to
# ado oayams.,reds
# ----
# iter 1900, loss: 78.655545
# ----
#  nraeat ec krofle ml n woraCiliol fuul. riscotin s whetlesr d
# bn teovhyag thyiIi linheom lhu ite blue we raCte thate mey n fre-syn
# oogetc fetinAa thereg dorpit cenomtaaloAfimdotm wions. O0itr-topuitin
# ----
# iter 2000, loss: 77.666060
# ----
#  asod e whteeseiuune wan od y   has che ha
# Cpe.iprrk nsd ’me lassr.lece no
# w h re to to n wo maye (asure p ale lssanes d to pcyn‘ige he 2es s d’hoso opolds tee dd cdim n thd arits..eKk t hlean. laeheln
# ----
# iter 2100, loss: 77.012222
# ----
#  meciloI ite wed pe wn "pone’st diimyt fanAnar f"co Sonfeuing zamy , bee tolast n mhranpd t slre d’n  Mf obe wo 1co nd "ipenim iw ohs dheny yoksd daf "t
# unre wvedothe., sut ave. n'y,e,.toend  vh te tn
# ----
# iter 2200, loss: 76.280276
# ----
#  e le, ceies g to w. to.d wa tothin pl yed, ot,, ihry."egun. wis
# coh ban’s  heecort pe do, aberice Che ngi— t yoaSist r I rg. Weghilt, gon maveowio n nl lc uy uns F sacn v us riso winw pan te Hor ouow
# ----
# iter 2300, loss: 75.521478
# ----
#  Tit mamaw ve, Os woin’,, yilole ran thee Kind ale o's Iur lechet tuinuly’mand bloranpe pe hibe To’Ede ikaveotasd Mey il. —hs inun ceon focs cois tadhe T Khe thy. I damu; ptintouse og be whees silyd I
# ----
# iter 2400, loss: 74.565215
# ----
#   mre Itapk t bh k koin we I onnn Tomr inodgb uI torensoves ’nesI Wolutt mimatosedit,us ce Yse’nilkd biun beowhavolas’lpane. kch pedy ilaf the t ld aJen’-’pl. gy t thupoe, lve ll totut alithk no wos wn
# ----
# iter 2500, loss: 73.789295
# ----
#   ide h leene lee k, atte, prand Woly sonangoml tat hainea0 1r tit t Otk inent e; ut noaemeroNre nsg utilW mond k ulp.
# 5nat ge’ntegr,edhtape btld wothicesee
# sine ueleusemeored .iaan sore Idsohe ul 3upe
# ----
# iter 2600, loss: 73.272632
# ----
#   uI win [ocpey te vandang are mp.dut.’t sngky mfy gr and Tf the ve.srd.. biy whey Irusifbe ung woundu ’iy lrlrle wous nnii.
# Me fs2r inwe wo Wit. oo.han nd taucpocaond rogeodplpos to $inges con. pyorem
# ----
# iter 2700, loss: 72.569329
# ----
#  Ie, n’ resithicu d bengs gidous aeitdle venetand tteyre l, he tos inand Psain, kn.t’e jhelSmay uhe Thace. natincs Cotm. bay tebt. al Tol tass’clulca uyt fr at te gan wy te toy ?deapy th foPorsethe bed
# ----
# iter 2800, loss: 71.816097
# ----
#  y bouseveothevkenlese inmlouh geat the I iraed te ahoaniey We a p -thave3 hthanetga’in. nthh  zee theloy khil p, Iaroiss tbealgeiltas. gra, doke thur,. Rhe thetacahao;iTy blolker.rlakereus aanjre rice
# ----
# iter 2900, loss: 71.086578
# ----
#  . Ans.? fo’ns avv pleind Iof n gid I. tvlo’n touy on’d en tuyg Itrm eceleig fhah ho ud anaon kly woix. beroutl, fe pias touil  vinos frheucd sheecroc. heod thanpot the I ve
# g pe ’st wet sowlg
# nama an
# ----
# iter 3000, loss: 70.606168
# ----
#  e qotf
# toilike,, tind merre th.n
# dirul s.palr  ben
#
# Aorepl u wthil in h tawe dD. bof amepet uns Snire weronng sDa ee,he ceet  ve nerse tte kaclerilstaint loto., gain.y pere. dhin r Wow,ureNbureei
# ge
# ----
# iter 3100, loss: 70.069906
# ----
#  rlyo 1uece thil ry worle Vkind fooo the, bhe waiL we ptin I phirle ngetand hoss as fo—ing Hen vesike w y’ly I gaBind IrItat I Toed behe tar f ut roonHt ok de
#
# 5 ch thihe cipveplen ha e n det, ": cere
# ----
# iter 3200, loss: 69.466050
# ----
#  n
# dam peg boif weretalselreant —adone noo’s es theucatopd ahaantadott?fre miko I Ie koun’d, Iord il orl an’t herand, po onr as thed hapou, uciigrehe igtind I.e Hen asatn I imy tot fne ge pily Henaass
# ----
# iter 3300, loss: 69.022738
# ----
#   eoafsinti, nin ikd bit il’ng’n tog timk y mafe to, any "Be ban4orqe Irere it I ion,.aA — Hliny po rocnor  ‘e nouren. An Mdtutr  cind ant priconut Obian y
# inrud ooI F.. therraret would ke’lessalor ihe
# ----
# iter 3400, loss: 68.370330
# ----
#  is., tithti, oudhethe
# xhponr of goey,r inr’the’g, Iro I wory. ft  he hand fe of I ive. and, I nd Tno aoderom l lort. ongit ss’l bit rs gone Kales totings 3lhas’unEt on xo 2ovr ko bantseat tuit "uma go
# ----
# iter 3500, loss: 67.944546
# ----
#  . t,s bir periml ly Vinre wuscol s angit ousltsnettis—obin ae tol nocoreoosorise eo Ir tisnd tre I ros’re jonon
#
# fd iemun riracle le., t'ad if re
#
#
# Lre noy ulvey s, ghapg fe wlis dhave indnralt touson
# ----
# iter 3600, loss: 67.541403
# ----
#  t thor co— the thes. We avy ghand mhl vek. hasledon  f’ow pe ve "I f.meivefhomlk. Te ave oy orrlesUotoiret eane hal mucein
# Wlen I Vvos nasele ATce Wo Ce 3uta keutty baby en thing avei,r thatoa tee mii
# ----
# iter 3700, loss: 67.106546
# ----
#  ungisat teld anounS.imut, whillut d plt, nave ene t tis mos theny I seink m ta wipt pt enat ulend ing. Afonll. ptey  ampvedaon ibino th o$usovy gexypel Coiy mve Mdarm ofothar tand mo1: I ua ghadov. aU
# ----
# iter 3800, loss: 66.659289
# ----
#  e torlebeec tadr on?.t Wo ta, bat cttvals gare fn. Daive the.,oC. —  b,il’s hey.,as corers the diyt thans thoriley ine gome to,reg. ofre pt to r liare hame jn oAt atoanoy t areacl;usticinedr ois fheok
# ----
# iter 3900, loss: 66.166664
# ----
#  ongrg Budey lharasouw Thifo llme oug  Yowilt uave thive uQ’nlew byitthe moes and anasilympmovt ort fot thasol tres blorllelg sicouan’rerligasl ibd tor rking lasmeoUs ive Iseon. komet inen coaOsen, ha
# ----
# iter 4000, loss: 65.643196
# ----
#   cheeye be the I,, aor rouy Somrinulot gung erse th ave  ut sok Nhot Pasow t ioglra wos, th.’s g wid ron uv mire orin the at ba bingore’ng lildoaley, age , —appe. We me ixar davit il divesrd man ang s
# ----
# iter 4100, loss: 65.335529
# ----
#  he.
#
# Isil thidtand ct,.’ thert t of at gato wast I  to cat t’k I b’se med lant ghet we andraves we lo’y thatp ve urolg..;e oul dhinond d. cowe r Thesr tharqn bero yowo be coar yhaut gon’my henw lharan
# ----
# iter 4200, loss: 64.851285
# ----
#   th.or. I’n. I’let ofeuker wroesu the te d le Yiny’n in hain focacle tete as. I Oe’ve th, fone. merllares.
# joed af yoto -
# Theor, p. Sond holk, 0vemis athiulut s id. The ersacind jf oon. Yibut —. he, c
# ----
# iter 4300, loss: 64.628540
# ----
#  nr on ueld we the ket hoat athad auirits in mo’l 0zesaan I’vcint Ixed me — leT of whoustuldo int thef tr fows yhocd mor t Pesro $W's. fopt petaagd be a le Bely an wirersiw, to merard thexlirl — onAme
# ----
# iter 4400, loss: 64.145215
# ----
#   haunl foing tehe ibles ghepesmims he’s iromousogang. Bathall $'o at. Ave p ’tll, o I thy btrit ou gdonr su tas, moaMe thas "!o thalisee wse piyyt ge Io dorf. Ky tattS, this beond We wwe lit mrovdre t
# ----
# iter 4500, loss: 63.799769
# ----
#  e coat.
#
# Imebord pallt morau goiw, wo de tout Aliny cigrir to meusant alg a th ufn te’lhe amlad ongeed sarbsst warn oon Oind bit andoi at acty foo tooul  hrt ghou’ng.
#
# I’be te hpeucg Bbim of ban to. T
# ----
# iter 4600, loss: 63.349379
# ----
#  re ?illley, the the I re nobe ghe eurlelimang lin’t’t alpdrs uSlely yif, of. Anduss’r aan tor5w theve te ghang hassme n’vkt — tad ive gy sove thy
# Me —cand saxed. —oy, sas to wee the lound tor astand
# ----
# iter 4700, loss: 62.925740
# ----
#  . pohopDs corell meam..2Rsouenk lat anWecip alt. I atps psake.’s lecannl’tt aninr atheret wos, Thathe lact giincon an, she ret iof., og thar plive
# mald krpee l., toules lof theld be hastt ierd. Eo’n g
# ----
# iter 4800, loss: 62.521586
# ----
#  s wo sat tror. Ne pauk haik thiced iwe sat. wheak the ame ing, toiln bat peidnth jop s r chey  ourid’d to ac.
# Tou ang gat. , meen — sadleg theeng thlr ghas meve’s san go won’nd ame.
# Tee uthimachat in’
# ----
# iter 4900, loss: 62.022201
# ----
#  d fhisingitit pilo tou e goxin thefat god carer ou"— ialke — to t5it, fost toindare so ig mer-t. Korazy Hes, thideve lein throf .e
# dily beazl bcas. Any ak are le eKroule —rtt acdcilr de ear.y u aan be
# ----
# iter 5000, loss: 61.799040
# ----
#  icou waen I chajd s, Iiman tl havet threuth hothas I — he to dillather’ty. bowelde ciche wb.
#
# 2F w ban our, e5 As an —. noup, yhmare’ng calk —’lke wanre  hame, meen  haye.
#
# I’clPs re y b, en’in de ao
# ----
# iter 5100, loss: 61.431349
# ----
#  t th in I’s be inengumy yors to — or go — fidt’s, I.. Thandy copn wr at veethhet Cr, then, an thereu foath, touctou 6om onrund mon
# waindorl Iu 1U —on bYil, isyto At (o sondca. sook le, fo fott I hate
# ----
# iter 5200, loss: 61.410273
# ----
#  onou gyild thiin’ecisstkis t’t Relw und,prain Sow the eon. Ulasen teod, any Ohe. I. Wevate is. I I she I ke be, bof mols  has. He three deut Hrsna iucly theuls lons — 63inigu hins them. Bea lo caho Ep
# ----
# iter 5300, loss: 61.303982
# ----
#  fyoece. Non’sce., jum. Hoh t re bhy.
# I’ng as iut foy we tha?s — he, woat, Hict.
#
#
#
#
# Thitis we nthere iniy, Thinild  f aid goo Yhe at in mous he any thit lo,, ing we the, meon tht’n gomi y I s theon d
# ----
# iter 5400, loss: 60.929441
# ----
#  gky 6e anyf have. Ave. Ryt ig nod.d,, ingrirlrong? Ane I jzet onive pankand’se noutM. In’t be harise’co ?
#
# I’t an aeknetiss, truuns re.
#
# Bd ins theve ou ref on’buiPt alrit let caks gonke yo tensyye sr
# ----
# iter 5500, loss: 60.565824
# ----
#  .
#
# E ran baon to n ero., th. Woo — heil ngo th — iute tot arat newy heovet, unisnd ive oulhe eret. fherly eloutres cimpe. I not dan S
# karg Eeatse wai the yo, ghepes miidng tare s ler.’ud $zeve the are
# ----
# iter 5600, loss: 60.204176
# ----
#  lhevedrt wing theeny imatr fotof, mamaghe inlhas heot, te hed, I incdwslave couat. An renitf souk fand thpyd ilg thetk to’m I Oucon bit.e abisrat it wit avs shany now, u k.su then I ase,  ok te thit.
# ----
# iter 5700, loss: 60.079758
# ----
#  r;d cau thk ker, So se het, theitil ton I Yof t utcen’s loke the cound, thlg bert songinpwe Wew mac Cek hentler tr, har t yom ok I chene we fin NoCalk tou coud tapus. widte wayy Eet."We pe lopiy b tha
# ----
# iter 5800, loss: 59.970952
# ----
#  it on whato to momevein ankeasrenthitt co thiyd the gibr out ag. wkoitbeygots yomet is thingereld. ipntrRuw)? Bou, —o komy sars venowsren ko dilit seusen to par thice d Toind weeg, cheer, non’ns y cha
# ----
# iter 5900, loss: 59.622238
# ----
#  at. So
# ‘banuy wor, wo , wh to thebicthay’rot ghint le there. Ame he, theve’lk g, ut no E, ou whang t. We’verron deen We. An’t
# zo’selt lemepd pir inkr. AheNales wryo  Banis what. So thereey mSeny 4s
# ----
# iter 6000, loss: 59.294249
# ----
#  whherit themat., Weowisstoi. Bwy gaD to ru roips ing me caid, whangst to incar. An loren gise d’thalks. Ar, thele thath to htine gibus toill, wa kn the ware thin anit weugts, thibet —’llce teoor Ye ar
# ----
# iter 6100, loss: 59.053461
# ----
#  rand gouip anghureore dinc ft mour dobly. The hare hasrey’’nd OXhicims Wangire. Hous. thathow the, to iy ong thare I wht tar morind ntit8m dety Ko gow moup coide rarich. Thavy anddod to’g, theletseldi
# ----
# iter 6200, loss: 58.934885
# ----
#  tho on’nb I f comy kiren o8 int lo ken tho Buve ay ang to we an’t? nove tao peild yoametIan don’gu hout the . Yhay ontat thaeeing Igaleibg thithit th’tp couve.
#
# Themink ops of to tosot lo no. Thabo ng
# ----
# iter 6300, loss: 58.813690
# ----
#  ur. I whaid thind lt Bute the alsane0 Mind lg ald wa win, Nat ponif. An’n  hek.tam we ibit,00 haoutirhind alafic 4ot aorst uy orer, kis pt’nk ines to to’nderees Afeddit aree imhitt mase iitand Theve t
# ----
# iter 6400, loss: 58.877825
# ----
#  f rag I.
# T "K'o lacanghes.."
#
# Buse doin mut harare tet it alk. WGauto ane ceon aik ssore gome arnoky Thave din erateedd to to ma my, ial orenet, on wand then the sus., Thete dict, I —s and a kodt thas
# ----
# iter 6500, loss: 58.615542
# ----
#   kin Nowey, angs oro he. Ho indtils, "Bat ongmit oulifuw hhob-ein Wer ane gon the machut, in g whe doud chay aven w o8 thery ru dremy wat nd aeds alit ale as yoveeingpele of wo tr wust lon tpety pang
# ----
# iter 6600, loss: 58.536043
# ----
#  rnlpiys bun wach toe ded,raal umd als eof lo tat teong. onopicrratc" whe’t. Af ve.
#
# But. Tharetind iinsed the dsalle savepeas ungo lkiy — peu kfro karP 5ming as a . I’y — a pemeng teeds pivey, an’twi1
# ----
# iter 6700, loss: 58.356424
# ----
#  tinls ease teare.indmat’go to ordeys. Afe mothe gor anitht we, mowe or I’ s’snes wheit Therallselilg uta the anes w ous so yod hsyrave  peg thavead Oroche ire hat we wousherit. Whant iou. ou got wanra
# ----
# iter 6800, loss: 58.183988
# ----
#   Fous, a we iy I’s, gI une, ta wiccete dan,  hilke e topycabs, voucp pame al theo lpisu thy sofyed at, ut’ir gowle,, pil. Yon’pd mef. The yoy’s jut. Afinl theme hean yow id outilt wpegou. Saf ilreca.
# ----
# iter 6900, loss: 58.313311
# ----
#  e."
#
#
# y thane thes and bave hontoin or put in’to souve it ve yoms mari. Nof at? Then pey maros, mas st it pimang. Buraceend whiipd thiy thly bingrof me the ang ior ay coubte herorelga he Cham filkto b
# ----
# iter 7000, loss: 58.044923
# ----
#  t — Casn.
# ehy doe the I. Theet. She ting thatn beod pts pige s oule we une hang thed. "u’ke re. W??…
#
# An’iy ven, wit tey thind E6, Cort’? Ag walg evamrny e, papl of now he. I’rin-use wis dothen ware b
# ----
# iter 7100, loss: 57.938951
# ----
#  t toind fheede gild to dea s aca to pnitmel out 2Fer, ind hess serist and souy 2 we pedy’s s riuke pall gbind gha] oUr thpan. By thedk eid. anasu Hoag heccesand I wout. — and we.de I, peusw mis. He’s,
# ----
# iter 7200, loss: 57.676279
# ----
#  ing wighenhmy couy got en’Ws they gor. ous ke zethe ped pit of, to thededon Beeb.0
# 'ce chet I And inor. Thand the wnut seve thashand I waatat Re, yoy ots. Soat thin. Ixou me as sor w. 1Ango boos, ro?
# ----
# iter 7300, loss: 57.446964
# ----
#  , whare they thed p ind dou ket igo wwee ba gonicang I I go ar.
# –e ale zee abon’npit no We pianes gaay eit the he ba.wed go to wacwirst be paryond wa kneton hate lrave gow sowe the. We gadthaw Thersh
# ----
# iter 7400, loss: 57.218130
# ----
#  i-pksel ong fous no tharlto theren tf.
#
#
#
# (ow amixsriy ghkek to wens got ave ootin’ve enr to. I ony thtind I binn been gorsilg no-l-s ou hat",  hey re ang no gopleabar antseevel th brig ang allago the
# ----
# iter 7500, loss: 57.149147
# ----
#  nd tho oW, to dangamsig. Noure thus at saln ous ony thincarr we yoreve terennte.
#
# T
# De dar, ta. febor it’ng po ofige wen ko so gold.
# Yers angrut ang ise by.er wove mere ing. I. Yog yor trenolt nut —.
# ----
# iter 7600, loss: 57.540650
# ----
#  ed beert, baint wert sourldr, ofis wy’re pound kn"
#
#
#
#
#
# Yous. We wainis iton.
#
# Thind it habe. We wico thets orven or pyw think. That maan waimemp to ming buele they Ns l."
#
#
#
#
# Gis seeng jeind toine’s
# ----
# iter 7700, loss: 57.545106
# ----
#  us catu berere oree to of AVd coon tal rug pyube thestped Sheritw geendoblit dany be'td be we this wincare thet’t4 bey ale, I we fono lie en’tce fe sen thee womorgesoutwe onoradabnd save setingith. Ix
# ----
# iter 7800, loss: 57.448362
# ----
#   te why We afe’th thenghered. Wedrit. Wagllam Wo ond ak. TRl cot’rise bey imer to be in toumh they cparey’we. We pear busigtikpenksecussexofe meangve w bo nond ilen Iull pped lorche citin, foth se is
# ----
# iter 7900, loss: 57.421593
# ----
#  ds sioze bere gomesrthas gheiiJat i sangs ofd woceer is, thexlrey goor beat dorl  Mibu nar to theyt I hand wout ce lrero inbat ther of of sry goud gor con thend af bavas hasem an tton inomlse shenibge
# ----
# iter 8000, loss: 57.443714
# ----
#  e rin theille pelictethinr I gule ang axt Midisim thes thy , wors if ofo of try peany sivet? Yopley toameshengpeatagtr. Thitr soxen fo OWe. Yvire hantt, So rsimy herit latif coy.
#
# F. fowat yove Gr sic
# ----
# iter 8100, loss: 57.881992
# ----
#  ns sint con ware simped. Theve wo waros. The, MEC— ill, ard sarist, fonsicastirl worts yoamd goanbem. to no aprer I atse chore to As guichink foreing we s ond bistalkns av, aux coure wofele kicof as u
# ----
# iter 8200, loss: 58.024777
# ----
#  is cared so redenghistis to thand this, I. To I pimf tor whe at ive hod thite nonguyey bing ilkeng comyag, on wpgigy ge, lemy illomre yoang noé, ontera foveel, pti tithbifnn’co gorestw we hacune fek a
# ----
# iter 8300, loss: 57.870703
# ----
#  eld furind Soren 'nd me has. He le we pam Nouth ont, pad Teinschariik ingay paut of have the beshr he thers sbinkinr da Une weincodekcas. An she sise asertis pOig. I soveuntpee 1e ofat Par. of, P0r of
# ----
# iter 8400, loss: 58.142747
# ----
#   inN, I sowigpend a gat Heipg ofald rotheng thirk wactalkenlemrole in icirin tom lls goumt insilt as heowllor and Mrrscuve it’re of therounosv and tu ubs sandowictonirtyytrint’rlt they thw They, somir
# ----
# iter 8500, loss: 58.172145
# ----
#  ngranf if fopd orste, ralus bto gorprrthate gry paplmrare dan'tinkmont, non ther thesad ig. Ta ly hit goreumisl’ts’ce at honty e an. OWe to fis pele gucreremaowe oud trarrit Snsytamoroikl wallt, sohit
# ----
# iter 8600, loss: 58.220410
# ----
#   ind tas wand."
#
#
#
#
# heok Ied sann gidorne hor udo bist. We dout achalg busss d.kcadit sicasf ave t is peeced anttit wot geed of we idte patald at moss pising 'ba hentheys. Thiak gobonsouciver we thet
# ----
# iter 8700, loss: 58.295537
# ----
#  tle S’nthropnotilrer onigjim int, an tilcme sice on the lathen. We poOall hertind abl, doresin, ils the dend ad intave He wise gtarpenoulo be thethse aed wat cuored ound thekl iyrr at go gus ingte ofe
# ----
# iter 8800, loss: 58.317673
# ----
#  aths loon’ll thos a kussuris.., of ils aple, we the,tinle. We lo’r beithraw wAn of ard whound to hey Fopler. Wa micas pe an weelly bonet, we hivede Ied pien the no goder thango ont upopllrant, fn
# gusy
# ----
# iter 8900, loss: 58.128066
# ----
#  chibdoven thestisil ijrin’sds.
# S homiinges ced pinwamingwish sha cofhicdat? And ouis dald, I whrts simpr toain Druod ghe, we gile seded ang nsmaak when it oren ssevath marted ve wowan pot andangoptinn
# ----
# iter 9000, loss: 58.216890
# ----
#  e allreis befon tos ofe to. Wu fabkmins of oulind irgy. The, ow ammey, dooig. It mouy gouto myel gouste  Wemalk, to Non ithion acesot ous itall avit pot ans meubiale dont sand, cey s gangs cas that  b
# ----
# iter 9100, loss: 58.351378
# ----
#  tmendonnt srebiilrrt angorlbed a the namis is kore titrimup orind fismted n’tisriplichely bet wand the’vareed barlescasr Pj. Bupl, yist to the wommee b1of. miratse abingt saun on ttalire , oult nirint
# ----
# iter 9200, loss: 58.543778
# ----
#   ghih, yopsuna. Awira th ravasiraby, alt charmrrorten’re Unow preercen’ yropte tnan eang sror tet.
# I ou’te artald se we’gks."
# We bene w, Ancenriy sone Larames tharlhinind te
# bhag init to Det’t beohed.
# ----
# iter 9300, loss: 58.668097
# ----
#   the acbrat I theree w bthathen Resher tontit sonttell I mere so foriged on, elte gt bo hror ar noe f of whanu he they weorang ticiave fomeraly coon whet ofre lorafas Ist on hesankit doracuthentt. And
# ----
# iter 9400, loss: 58.670925
# ----
#  iveeas, wo woa dot’ hablrann he. They’se an
# An inisw ald ofus meas thumman drorP. I thegrapleyyryous whrat as efr. Tho the hacleAs nos hatile mero le ou anop amillpato cheotmistinout the is t jbot. Ce
# ----
# iter 9500, loss: 58.708727
# ----
#  or. Ieysydistalintse’ry ppec1 Iy Unceon’l so aray whe he $ffed babl uy. Anom thee dhictte ceryale, irt at thathacy what atis dor waphery yor d ere Hare bond.
# Ureale, barind anand asind cout aliy in wo
# ----
# iter 9600, loss: 58.610588
# ----
#   OKl bylend ous wak oren taaldry on fuy. We whim onR Ank ofrist of buche paslispo loo1 Chot hrop ceritr prrits on t.,.
# Yof ;ugh py. Agiw theble eIr.
# Bum and the momand thron thend thaumit’alive foren
# ----
# iter 9700, loss: 58.349844
# ----
#  ly OB I. I bet It’t gfkasceillevim. Tankliging forcind foror sre woalitr dicarenow Upen wtictingistsr. I udcany yop,’t teevc vew Syrit thes. Mutlk thace ton Wuplat’s the mand sthrechmanr ovend ir dere
# ----
# iter 9800, loss: 58.278837
# ----
#   Iow. He. Iep on I hit the hicifyire the gorescisn tobruon, domlen thitile diclevetrecan’ll iidendas oun’r yhicitu anag or’me ila alassiy antivY.sow. The, yact apreeing te, ave iatory Allly
# No$Xe thes
# ----
# iter 9900, loss: 58.323659
# ----
#  pnare pleasr appimacleser whou. We tes tive I h.
# Bunow weiths gicand beis, cave in doulnctoistive toelintirs. Wis thicpungreas Aevin Wped tousiypt poud ourte callotherrrit merat to bust as maus, cowhe
# ----
# iter 10000, loss: 58.241061
# ----
#  O] douk fall s, Fit ilild o= muccoree t'yw to nown ne cat nitre fed worowmre, thinthr lexs have  pire igsis, thignt Peiniry sfustis bets, soisin pto bave sades at mfpree Stin w to ghuve thank rey Sos
# ----
# iter 10100, loss: 58.295145
# ----
#  as, acandare we tod yon wtranf we al op, intust utiy voreg abed thasale eoginen cortto Ann oBlat.
#
# Wu. That. We wor alt co pe;rso yandtytrustindst tholle ans, pountbate midrefn ghry hand we’t ofppto t
# ----
# iter 10200, loss: 58.146645
# ----
#  is yad Mor whe dilly whar acpekese ben riomnpithnder ofill ould I noI wopsiiteed, you wre. Whane bed thiches exall ounrr rmedee ped agtiof atf thd aming he ceden%e thlan the hersy pay losind on’sispat
# ----
# iter 10300, loss: 58.436913
# ----
#  forite woativenthat pouzir no The the icavy gorvnut and thing woty do parors condor  to worlutointem r-anlle pavethan Seey sseld ande to goplin’ud wnrachachso thitatiteot, dircounim luablng ire bowas
# ----
# iter 10400, loss: 58.437637
# ----
#  l ofr oud ofrtydistoizaithe ilpory icantracat of bent tey tag fef midire wieddail rato, to meint trevenane wboinr inroer vy Ariston Undise bials I’s the walgnok ids He ald ses norictictamanticicaf ang
# ----
# iter 10500, loss: 58.503437
# ----
#  estrtiom hat caller an dowSeanseps orinwicto wething icidy Sro yoor ane, They, bonay wosel pow3 ibryysto tuousey orlteiss Noulo als to then bpristh the aren’lt boreo- to "ures bald on wang tallirario
# ----
# iter 10600, loss: 58.492037
# ----
#   ata bun oristus indwhs cicis thisr, (Lashetapecnths he coreare as wasdryo,, tor ating tham aund whe bowe te dus’m thel ilicf angof We dats boe co dut wicfep at’s Detued Deacgenting the iste preryamop
# ----
# iter 10700, loss: 58.566317
# ----
#   biy want iar. Anat fos thill we Bendoundy theoberill ower ates iny gor ang pruchaskm be ifof.
# Se ghenould id bnous, the nabe the beson wha dosthe ineng o! arinl hand nofr Ribl, eeple teisin and ned t
# ----
# iter 10800, loss: 58.099080
# ----
#  f thor, t of thrus me ton gort the., cors I at tu agy to wempi pundire co haningren in dere me the
# I aliin azils at be? of agy
# Muss ons we gofabins whe ans santhiminghe tansto the hir3 of With warig k
# ----
# iter 10900, loss: 57.891102
# ----
#  a. Wo Pe pant.
# I thwey apSticice thept the fonge to dot caplere berpt kar anf at ju t, wo gat bad Deliakive imatal andabt gung and "Lole ;ow oud bum be that rarn why he thing CroT and.
# Theou gerintts
# ----
# iter 11000, loss: 57.888619
# ----
#  rixale of pep with ther king Co dis whitsetht’e  fo gfere thas dah when pt’s tiak den. Of palltses peics."Sat. War this doridc. Iey iam paske tiel wo ant of poutht se weegin the cedllke wee the lory t
# ----
# iter 11100, loss: 57.700440
# ----
#  9de beome whe. An’midycan bely Thar butcor, yomery I "Qus , the is. Rume ind inarlcoreell me Shanthons Ho ape fou paren Iddeng comale pqcthiy
#
# Thig phemi ing and toins engu hof tre soing. Yo with and
# ----
# iter 11200, loss: 57.660066
# ----
#  de a vebe inly Pa’mson’res st wmape treca komls, munl faold orrt erot peimitkos yout’re. Clithe.
# Bo siy aca nots rion Be a en pase in go’ k mamc, bes isayy.. Youlletintmith am ill elomrotr.
# Yhareeve b
# ----
# iter 11300, loss: 57.468375
# ----
#  on wacnow Guld aliy thamind bigis vumite, an, "I, pcang jo dober. Euy, therasive in I yout buan $50, yhe tipest yuplis theo to they we’w— bexigiy. Bu’g ig ghed. — tangtat ooxbeou cathis be hang at, eg
# ----
# iter 11400, loss: 57.284651
# ----
#  d yours Nang to gos, ame itstyns sone.
#
# hacl wint Cobes to toed ita o gos buto s abem ake.
# We. Trou, in thistaiby wotue ttrt ar the? Aningpesden of. Teverecnde gor kand the leop loop, wasad nid the he
# ----
# iter 11500, loss: 57.204240
# ----
#  otor po ttocey peter was itmall cheor ou. Hangaste. The buy the wr’ca goadesietring youth SCing upldet llew, hay.ing bv, woow soof mon gmall Sig inow? No oned, halk –rechunlrid aot?
#
# Bo no’tedeab phap
# ----
# iter 11600, loss: 57.101514
# ----
#   ghigh. Howy Se euy in povent He’ls Sory not fta’s toble to belteat ever weak bulk ovbon Ies don. Horle. Way anase?nort.
# Nougf? I po’rit nor ntlaw thes. But n orlleng icrtan fo’ praly tow2 hag oullen
# ----
# iter 11700, loss: 57.051536
# ----
#   inokltier the re’le a penerand howe – weo sane irales , mey poin tSoushan wag tiinf tho the ano thk we’se alvenob. Biedtso s. Youns."
# Theat futy wheo Mes?
# Hace thatining doulst. Wamilthos. hone, the
# ----
# iter 11800, loss: 56.796728
# ----
#  ose. I’t the Jer. Thade orlk. Wpyoute wody eymp to aty – I wenat kenek tall, miviond there thet top won’t wancomiy thay wiridand the Thabery’gss. I bel Sovemeth bom Haye te tho  ho mido buig. Iuribg b
# ----
# iter 11900, loss: 56.540831
# ----
#   pe sustu thave so mean need I me matleg Notey, is funt beogd. Seing So bep Man dow haukd beem yor. The. Thex te edes lise lo cone onlpy havk, coumit’t. Wo I he’r aband sous exd shelgrem. Runp avere w
# ----
# iter 12000, loss: 56.455520
# ----
#  they Hly’mtr. Thisteure OLe rede to’rd the mourase jedes tiy mif wamMre k, thens at ond at angeverang bu sharon thave Me toindgunepll bedyyt. You noe’stst pry, aningops of I beinlangem bagl Hing the t
# ----
# iter 12100, loss: 56.493367
# ----
#   "P ovenimronte bes abiacasl uslich an gilk aus n1 ftalis. Of herin wrop tay bull thero dob's the hmonlare’Es me uucay. OBd wpongt dors ou Perind ppofdey cath ee the and "Thetingt seemer to Of hedsita
# ----
# iter 12200, loss: 56.470449
# ----
#  ll’s the the. Efus fyou in Con. Okr eof Ang leplellouchen Pald lo F gn’re stis ou l:uy. But. Tper I piChbyes I wnor Trow goryrle, I wethacigre – I jous the in noba he’s (ing ag."I dais med ve paov. Hh
# ----
# iter 12300, loss: 56.269196
# ----
#  r hen’t in wavat’)l mif ikswat doume to dosy we’s The s orece kf ino tomsiif lon’t of not thask hn mifr thalhe gies salling lobesecagit nubt beleress.
# Burronit a do unt, wabgson’s thelley. We sersted
# ----
# iter 12400, loss: 56.283196
# ----
#   co ing ang yis the e
# "
# d, Sor the Men Itr so to was enat.
# We in[ gomiy poing paus. hor’s ohingtis of in Mimenk, thing bele theben’rs orncyictindySen mitu guy mafine. And is oparl’ce in tonten’s aef a
# ----
# iter 12500, loss: 56.201137
# ----
#  t fot I’seed issy abik noy. Buss y able gyyer oum, the’perifrsat Ure to woind kais, fum lealln’t – I juvey’s .I’tend hisito gos. whem ildmow solleen. They. Ana. &ophe goupans lto tre – "I’me I whece w
# ----
# iter 12600, loss: 56.017421
